# %%
! pip install fastapi
! pip install uvicorn
# Out:
# Collecting fastapi
#   Downloading fastapi-0.75.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.1 MB/s
# Collecting starlette==0.17.1
#   Downloading starlette-0.17.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.9 MB/s
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#      |████████████████████████████████| 10.9 MB 25.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from starlette==0.17.1->fastapi) (3.10.0.2)
# Collecting anyio<4,>=3.0.0
#   Downloading anyio-3.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.7 MB/s
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.0.0->starlette==0.17.1->fastapi) (2.10)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: sniffio, anyio, starlette, pydantic, fastapi
# Successfully installed anyio-3.5.0 fastapi-0.75.1 pydantic-1.9.0 sniffio-1.2.0 starlette-0.17.1
# Collecting uvicorn
#   Downloading uvicorn-0.17.6-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.6 MB/s
# Collecting h11>=0.8
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.5 MB/s
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.5.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn) (7.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from uvicorn) (3.10.0.2)
# Installing collected packages: h11, asgiref, uvicorn
# Successfully installed asgiref-3.5.0 h11-0.13.0 uvicorn-0.17.6

# %%
# !pip install ngrok
# Out:
# Collecting ngrok
#   Downloading ngrok-0.1.6.tar.gz (3.5 kB)
# Collecting ping
#   Downloading ping-0.2.tar.gz (10 kB)
# WARNING: Discarding https://files.pythonhosted.org/packages/03/ac/9a3f332f8d7d27cd8929922b2e225842c1623760364b37fc79dc0f65e77d/ping-0.2.tar.gz#sha256=ecb32294c2af8ae075de4a3743f568db376480ad81c2e010a7f1ce1cee7b030f (from https://pypi.org/simple/ping/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading ping-0.1.tar.gz (10 kB)
# WARNING: Discarding https://files.pythonhosted.org/packages/e6/e1/0d6a865e59fc27e13c0f39afea889f34a62b209046bfb863b62b614e5a3a/ping-0.1.tar.gz#sha256=e86c646487241be6e44262b182f0fbfdc2c00f2a4a0b7b3f0c499137957d81c1 (from https://pypi.org/simple/ping/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting ngrok
#   Downloading ngrok-0.1.5.tar.gz (3.5 kB)
#   Downloading ngrok-0.1.4-py3-none-any.whl (4.3 kB)
#   Downloading ngrok-0.0.1.tar.gz (1.4 kB)
# Building wheels for collected packages: ngrok
#   Building wheel for ngrok (setup.py) ... done
#   Created wheel for ngrok: filename=ngrok-0.0.1-py3-none-any.whl size=3061 sha256=22faf702011c68f99301727bd48e51fdbe2f5aaa0635ba0cd7ff550f886bf8ff
#   Stored in directory: /root/.cache/pip/wheels/b2/f2/1e/11e57b35a7c1ea622a4cff4d9622bebd373f6371f3b1728a00
# Successfully built ngrok
# Installing collected packages: ngrok
# Successfully installed ngrok-0.0.1

# %%
! pip install fastapi nest-asyncio pyngrok uvicorn
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.7/dist-packages (0.75.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (1.5.4)
# Collecting pyngrok
#   Downloading pyngrok-5.1.0.tar.gz (745 kB)
#      |████████████████████████████████| 745 kB 4.2 MB/s
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.7/dist-packages (0.17.6)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from fastapi) (1.9.0)
# Requirement already satisfied: starlette==0.17.1 in /usr/local/lib/python3.7/dist-packages (from fastapi) (0.17.1)
# Requirement already satisfied: anyio<4,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from starlette==0.17.1->fastapi) (3.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from starlette==0.17.1->fastapi) (3.10.0.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.0.0->starlette==0.17.1->fastapi) (2.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.0.0->starlette==0.17.1->fastapi) (1.2.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok) (3.13)
# Requirement already satisfied: asgiref>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn) (3.5.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.7/dist-packages (from uvicorn) (0.13.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn) (7.1.2)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19007 sha256=e83674a4fd5e3242d076f918e7b7f1a5eed12e558de9cad4bf7e8207e7b11273
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-5.1.0

# %%
# !ngrok authtoken 27MPqTP08OZmu7nhHcg5mAwWOtO_5LHru2zc16V2qZpdkYCbT
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
from fastapi import FastAPI
import nest_asyncio
from pyngrok import ngrok
import uvicorn
app = FastAPI()
@app.get('/')
async def home():
  return 'Hello World'
ngrok_tunnel = ngrok.connect(8000)
print ('Public URL:', ngrok_tunnel.public_url)
nest_asyncio.apply()
uvicorn.run(app, host='0.0.0.0', port=8000)
# Out:
# INFO:     Started server process [63]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# Public URL: http://00f2-104-155-223-68.ngrok.io
# INFO:     14.44.84.225:0 - "GET / HTTP/1.1" 200 OK
# INFO:     58.123.220.11:0 - "GET / HTTP/1.1" 200 OK
# INFO:     14.44.84.225:0 - "GET / HTTP/1.1" 200 OK
# INFO:     14.44.84.225:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     14.44.84.225:0 - "GET / HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [63]

# %%
import requests

url = "http://00f2-104-155-223-68.ngrok.io"

payload={}
headers = {}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# <html lang="en-US">
# 	<head>
# 		<meta charset="utf-8">
#     <meta name="author" content="ngrok">
#     <meta name="description" content="ngrok is the fastest way to put anything on the internet with a single command.">
#     <meta name="robots" content="noindex, nofollow">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
# 		<link id="style" rel="stylesheet" href="https://cdn.ngrok.com/static/css/error.css">
# 		<noscript>Tunnel 00f2-104-155-223-68.ngrok.io not found (ERR_NGROK_3200)</noscript>
# 		<script id="script" src="https://cdn.ngrok.com/static/js/error.js" type="text/javascript"></script>
# 	</head>
# 	<body id="ngrok">
# 		<div id="root" data-payload="eyJjZG5CYXNlIjoiaHR0cHM6Ly9jZG4ubmdyb2suY29tLyIsImNvZGUiOiIzMjAwIiwibWVzc2FnZSI6IlR1bm5lbCAwMGYyLTEwNC0xNTUtMjIzLTY4Lm5ncm9rLmlvIG5vdCBmb3VuZCIsInRpdGxlIjoiTm90IEZvdW5kIn0="></div>
# 	</body>
# </html>
