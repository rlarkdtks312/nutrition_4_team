# %% [markdown]
# ## 필요 모듈 불러오기

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import glob
from PIL import Image
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D,Dense,Flatten,Dropout,MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator

# %%
cd /content/drive/MyDrive/안봐도보이조_project
# Out:
# /content/drive/.shortcut-targets-by-id/1SJQekhA0CeMNytl0fjgy05kskJWHvJRt/안봐도보이조_project

# %% [markdown]
# ## 이미지 생성기 선언

# %%
train_datagen = ImageDataGenerator( 
        rescale=1./255,         # 픽셀 값을 0~1 범위로 변환
        rotation_range=40,      # 40도까지 회전
        width_shift_range=0.2,  # 20%까지 좌우 이동
        height_shift_range=0.2, # 20%까지 상하 이동
        shear_range=0.2,        # 20%까지 기울임
        zoom_range=0.2,         # 20%까지 확대
        horizontal_flip=True,   # 좌우 뒤집기
    )
train_generator = train_datagen.flow_from_directory(
    './train_10',
    batch_size=64,      
    class_mode='categorical', 
    target_size=(128, 128)) 
valid_datagen = ImageDataGenerator(rescale=1./255) # 스케일링만 진행
valid_generator = valid_datagen.flow_from_directory('./valid_10',
                                                    batch_size=16,      
                                                    class_mode='categorical', 
                                                    target_size=(128, 128))

test_datagen = ImageDataGenerator(rescale=1./255) # 스케일링만 진행
test_generator = test_datagen.flow_from_directory('./test_10',
                                                  batch_size=8,      
                                                  class_mode='categorical', 
                                                  target_size=(128, 128),shuffle=False)
# Out:
# Found 10529 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.
# Found 500 images belonging to 10 classes.

# %% [markdown]
# ## 모델 생성 및 학습
# - ResNet50 모델 사용
# - early_stopping, modelcheckpoint 적용

# %%
resnet50 = tf.keras.applications.ResNet50(
    include_top=False,
    input_shape=(128 ,128 ,3))

model = Sequential()
model.add(resnet50)
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_1 (Dense)             (None, 10)                327690
#
# =================================================================
# Total params: 23,915,402
# Trainable params: 23,862,282
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=5)

# %%
model_path = './김강산/model/RedNet50_05.hdf5'

checkpointer = ModelCheckpoint(filepath=model_path, monitor='val_loss', 
                               verbose=1, save_best_only=True)

# %%
history = model.fit(train_generator,
                    steps_per_epoch=100, 
                    epochs=100,
                    validation_data=valid_generator,
                    validation_steps=30,
                    callbacks=[early_stopping_callback, checkpointer])
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 0.9888 - accuracy: 0.8336
# Epoch 1: val_loss improved from inf to 10095606784.00000, saving model to ./김강산/model/RedNet50_05.hdf5
# 100/100 [==============================] - 212s 2s/step - loss: 0.9888 - accuracy: 0.8336 - val_loss: 10095606784.0000 - val_accuracy: 0.0833
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4447 - accuracy: 0.9359
# Epoch 2: val_loss improved from 10095606784.00000 to 2.31440, saving model to ./김강산/model/RedNet50_05.hdf5
# 100/100 [==============================] - 118s 1s/step - loss: 0.4447 - accuracy: 0.9359 - val_loss: 2.3144 - val_accuracy: 0.0938
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2448 - accuracy: 0.9595
# Epoch 3: val_loss did not improve from 2.31440
# 100/100 [==============================] - 88s 877ms/step - loss: 0.2448 - accuracy: 0.9595 - val_loss: 2.5513 - val_accuracy: 0.0875
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9670
# Epoch 4: val_loss improved from 2.31440 to 2.30250, saving model to ./김강산/model/RedNet50_05.hdf5
# 100/100 [==============================] - 75s 744ms/step - loss: 0.1100 - accuracy: 0.9670 - val_loss: 2.3025 - val_accuracy: 0.1146
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9713
# Epoch 5: val_loss did not improve from 2.30250
# 100/100 [==============================] - 67s 671ms/step - loss: 0.0834 - accuracy: 0.9713 - val_loss: 2.3164 - val_accuracy: 0.1083
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9840
# Epoch 6: val_loss did not improve from 2.30250
# 100/100 [==============================] - 62s 619ms/step - loss: 0.0511 - accuracy: 0.9840 - val_loss: 2.3304 - val_accuracy: 0.1125
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9897
# Epoch 7: val_loss did not improve from 2.30250
# 100/100 [==============================] - 60s 598ms/step - loss: 0.0293 - accuracy: 0.9897 - val_loss: 2.6319 - val_accuracy: 0.1042
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 0.7586 - accuracy: 0.9661
# Epoch 8: val_loss did not improve from 2.30250
# 100/100 [==============================] - 60s 597ms/step - loss: 0.7586 - accuracy: 0.9661 - val_loss: 3.0777 - val_accuracy: 0.0979
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 0.8821 - accuracy: 0.7770
# Epoch 9: val_loss improved from 2.30250 to 1.95761, saving model to ./김강산/model/RedNet50_05.hdf5
# 100/100 [==============================] - 65s 647ms/step - loss: 0.8821 - accuracy: 0.7770 - val_loss: 1.9576 - val_accuracy: 0.5979
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3196 - accuracy: 0.9198
# Epoch 10: val_loss improved from 1.95761 to 1.63158, saving model to ./김강산/model/RedNet50_05.hdf5
# 100/100 [==============================] - 65s 644ms/step - loss: 0.3196 - accuracy: 0.9198 - val_loss: 1.6316 - val_accuracy: 0.6333
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9566
# Epoch 11: val_loss improved from 1.63158 to 0.30201, saving model to ./김강산/model/RedNet50_05.hdf5
# 100/100 [==============================] - 65s 650ms/step - loss: 0.1262 - accuracy: 0.9566 - val_loss: 0.3020 - val_accuracy: 0.8938
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9617
# Epoch 12: val_loss improved from 0.30201 to 0.10209, saving model to ./김강산/model/RedNet50_05.hdf5
# 100/100 [==============================] - 64s 635ms/step - loss: 0.0994 - accuracy: 0.9617 - val_loss: 0.1021 - val_accuracy: 0.9583
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9680
# Epoch 13: val_loss did not improve from 0.10209
# 100/100 [==============================] - 60s 601ms/step - loss: 0.0918 - accuracy: 0.9680 - val_loss: 0.1676 - val_accuracy: 0.9583
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9802
# Epoch 14: val_loss improved from 0.10209 to 0.02919, saving model to ./김강산/model/RedNet50_05.hdf5
# 100/100 [==============================] - 65s 650ms/step - loss: 0.0563 - accuracy: 0.9802 - val_loss: 0.0292 - val_accuracy: 0.9958
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9886
# Epoch 15: val_loss improved from 0.02919 to 0.01303, saving model to ./김강산/model/RedNet50_05.hdf5
# 100/100 [==============================] - 66s 649ms/step - loss: 0.0335 - accuracy: 0.9886 - val_loss: 0.0130 - val_accuracy: 0.9958
# Epoch 16/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0340 - accuracy: 0.9874
# Epoch 16: val_loss did not improve from 0.01303
# 100/100 [==============================] - 61s 605ms/step - loss: 0.0340 - accuracy: 0.9874 - val_loss: 0.0135 - val_accuracy: 0.9958
# Epoch 17/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9891
# Epoch 17: val_loss improved from 0.01303 to 0.00455, saving model to ./김강산/model/RedNet50_05.hdf5
# 100/100 [==============================] - 64s 641ms/step - loss: 0.0319 - accuracy: 0.9891 - val_loss: 0.0046 - val_accuracy: 0.9979
# Epoch 18/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9867
# Epoch 18: val_loss did not improve from 0.00455
# 100/100 [==============================] - 61s 602ms/step - loss: 0.0412 - accuracy: 0.9867 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 19/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9877
# Epoch 19: val_loss did not improve from 0.00455
# 100/100 [==============================] - 70s 703ms/step - loss: 0.0408 - accuracy: 0.9877 - val_loss: 0.0342 - val_accuracy: 0.9812
# Epoch 20/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9900
# Epoch 20: val_loss did not improve from 0.00455
# 100/100 [==============================] - 65s 645ms/step - loss: 0.0299 - accuracy: 0.9900 - val_loss: 0.0838 - val_accuracy: 0.9688
# Epoch 21/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9892
# Epoch 21: val_loss did not improve from 0.00455
# 100/100 [==============================] - 62s 615ms/step - loss: 0.0367 - accuracy: 0.9892 - val_loss: 0.1378 - val_accuracy: 0.9625
# Epoch 22/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9948
# Epoch 22: val_loss did not improve from 0.00455
# 100/100 [==============================] - 61s 609ms/step - loss: 0.0179 - accuracy: 0.9948 - val_loss: 0.0068 - val_accuracy: 0.9979

# %%
model.evaluate(test_generator)
# Out:
# 63/63 [==============================] - 281s 5s/step - loss: 0.0030 - accuracy: 1.0000
# [0.003037533024325967, 1.0]

# %%
# 모델 학습 과정 시각화
plt.figure(figsize=(16,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc=0)

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc=0)

# %%
pred.argmax()

# %%
train_generator.class_indices

# %%
result_dict = dict(map(reversed, train_generator.class_indices.items()))
# 딕셔너리의 key, values 뒤집기
result_dict

# %%
result_dict[pred.argmax()]

# %%
categories = list(result_dict.values())
# 딕셔너리의 value 값을 리스트로 받기
categories

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

np.set_printoptions(precision=2)

Y_pred = model.predict(test_generator)
classes = test_generator.classes[test_generator.index_array]
y_pred = np.argmax(Y_pred, axis=1)  # Returns maximum indices in each row

class_names = categories

print('-- Confusion Matrix --')
print(confusion_matrix(classes, y_pred))



print('-- Classification Report --')
print(classification_report(classes, y_pred, target_names=class_names))
